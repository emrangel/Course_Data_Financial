# %% [markdown]
# <a href="https://colab.research.google.com/github/emrangel/Course_Data_Financial/blob/main/Course/class/scripts/data_analyst.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tutorial sobre `yfinance`
#
# **Save**
# Course/class/scripts/data_analyst.ipynb
#
# Esta librería es una de las más populares porque "extrae" los datos públicos de Yahoo Finance de forma gratuita y los organiza de manera impecable. Aquí tienes una guía paso a paso diseñada para que no te pierdas, incluso si Python es nuevo para ti.

# %%
# Instalamos la librería (solo se hace una vez)
# !pip install -q yfinance

# %%
import yfinance as yf
import pandas as pd # Usaremos pandas para manejar las tablas de datos
import numpy as np
import matplotlib.pyplot as plt # para realizar gráficos simples

# %% [markdown]
# **El objecto** `yf.Ticker()`
#
# `yf.Ticker()` es para hacer una "radiografía" profunda de una sola empresa. Es el objeto que te permite acceder a los estados financieros, dividendos, accionistas y mucho más.
#
# * `.info`	Diccionario con ratios, sector y descripción.
#
# * `.history(period=...)`	Precios históricos (igual que download pero para uno solo).
#
# * `.financials`	Estado de resultados (Ingresos, Gastos, Utilidad).
#
# * `.balance_sheet`	Balance general (Activos, Pasivos, Patrimonio).
#
# * `.cashflow`	Estado de flujo de efectivo.
#
# * `.news`	Lista con las últimas noticias publicadas.
#
# * `.calendar`	Fechas próximas (Reporte de ganancias, dividendos).

# %% [markdown]
# ### Lista de tickers IBEX35
#
# * ANA.MC	Acciona
# * ACX.MC	Acerinox
# * ACS.MC	ACS
# * AENA.MC	Aena
# * AMS.MC	Amadeus
# * MTS.MC	ArcelorMittal
# * SAB.MC	Banco Sabadell
# * SAN.MC	Banco Santander
# * BKT.MC	Bankinter
# * BBVA.MC	BBVA
# * CABK.MC	CaixaBank
# * CBRE.MC	Cellnex
# * ENG.MC	Enagás
# * ELE.MC	Endesa
# * FER.MC	Ferrovial
# * FLUI.MC	Fluidra
# * GRF.MC	Grifols
# * IAG.MC	IAG
# * IBE.MC	Iberdrola
# * ITX.MC	Inditex
# * IDR.MC	Indra
# * COL.MC	Inm. Colonial
# * LOG.MC	Logista
# * MAP.MC	Mapfre
# * MEL.MC	Meliá Hotels
# * MRL.MC	Merlin Prop.
# * NTGY.MC	Naturgy
# * RED.MC	Redeia
# * REP.MC	Repsol
# * ROVI.MC	Rovi
# * SCYR.MC	Sacyr
# * SLBA.MC	Solaria
# * TEF.MC	Telefónica
# * UNI.MC	Unicaja
# * PUIG.MC	Puig Brands

# %% [markdown]
# ### Lista de Crypto Monedas
# * BTC-USD: Bitcoin
# * ETH-USD: Ethereum
# * SOL-USD: Solana
# * BNB-USD: Binance Coin
# * XRP-USD: Ripple

# %% [markdown]
# ### Lista de Materias Primas
#
# * GC=F	Oro (Gold)	Metales Preciosos
# * SI=F	Plata (Silver)	Metales Preciosos
# * CL=F	Petróleo Crudo (WTI)	Energía
# * BZ=F	Petróleo Brent	Energía
# * NG=F	Gas Natural	Energía
# * HG=F	Cobre	Metales Industriales
# * ZC=F	Maíz (Corn)	Agrícola
# * ZW=F	Trigo (Wheat)	Agrícola
# * KC=F	Café	Agrícola
# * CC=F	Cacao	Agrícola

# %% [markdown]
# ### Lista de Monedas más habituales
# * EURUSD=X	Euro / Dólar	El par más negociado del mundo.
# * USDJPY=X	Dólar / Yen Japonés	Refugio seguro y clave para el comercio en Asia.
# * GBPUSD=X	Libra Esterlina / Dólar	La "Cable", fundamental para el mercado de Londres.
# * USDCHF=X	Dólar / Franco Suizo	Considerada la moneda refugio por excelencia.
# * AUDUSD=X	Dólar Australiano / Dólar	Moneda "commodity" (ligada a materias primas).
# * USDCAD=X	Dólar / Dólar Canadiense	Muy ligada al precio del petróleo.
# * USDCNY=X	Dólar / Yuan Chino	Clave para entender la macroeconomía de China.
# * USDHKD=X	Dólar / Dólar de Hong Kong	Importante por su sistema de tipo de cambio fijo (peg).
# * USDNZD=X	Dólar / Dólar Neozelandés	Moneda relevante para el carry trade.
# * USDMXN=X	Dólar / Peso Mexicano	La moneda más líquida de los mercados emergentes.

# %% [markdown]
# **Extraer datos de una sola Acción (Ticker)**
#
# En finanzas, cada activo tiene un "Ticker". Vamos a descargar los datos históricos de **Apple** (AAPL).

# %%
# Creamos un objeto 'Ticker' para Apple
apple = yf.Ticker("AAPL")

# Descargamos el historial de precios de los últimos 5 días
hist = apple.history(period="5d")

# Mostramos el resultado
hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2026-03-02 00:00:00-05:00  262.410004  266.529999  260.200012  264.720001
# 2026-03-03 00:00:00-05:00  263.480011  265.559998  260.130005  263.750000
# 2026-03-04 00:00:00-05:00  264.649994  266.149994  261.420013  262.519989
# 2026-03-05 00:00:00-05:00  260.790009  261.559998  257.250000  260.290009
# 2026-03-06 00:00:00-05:00  258.630005  258.769989  254.369995  257.459991
#
#                              Volume  Dividends  Stock Splits
# Date
# 2026-03-02 00:00:00-05:00  41827900        0.0           0.0
# 2026-03-03 00:00:00-05:00  38568900        0.0           0.0
# 2026-03-04 00:00:00-05:00  39803100        0.0           0.0
# 2026-03-05 00:00:00-05:00  49658600        0.0           0.0
# 2026-03-06 00:00:00-05:00  41094000        0.0           0.0

# %% [markdown]
# **Valores para** `period`
#
# "1d":1 day
#
# "5d":5 days
#
# "1mo":1 month
#
# "3mo":3 months
#
# "6mo":6 months
#
# "1y":1 year
#
# "2y":2 years
#
# "5y":5 years
#
# "10y":10 years
#
# "ytd":Year‑to‑date
#
# "max": Maximum available historical data

# %% [markdown]
# **Resultado:** Obtendrás una tabla (DataFrame) con las columnas: Open (Apertura), High (Máximo), Low (Mínimo), Close (Cierre), Volume (Volumen) y Dividendos.

# %% [markdown]
# **Commodities y Criptomonedas**
#
# `yfinance` no solo sirve para acciones. Solo necesitas conocer el código correcto.
#
# **Oro (Gold)**: GC=F (Futuros de oro)
#
# **Bitcoin**: BTC-USD

# %% [markdown]
# **Parámetros Principales de** `yf.download()`
#
# ### Ejemplo de una descarga configurada con varios parámetros
#
# Para descargar varios tickers se usa `download()`, pero esto genera dataframes con 2 índices de títulos de columna
#
# ```
# data = yf.download(
#     tickers = "AAPL MSFT TSLA",  # Activos
#     start = "2023-01-01",        # Fecha inicio
#     end = "2023-12-31",          # Fecha fin
#     interval = "1d",             # Frecuencia
#     group_by = 'ticker',         # Organización de columnas
#     auto_adjust = True,          # Ajuste de precios
#     prepost = False,             # Datos fuera de rueda
#     threads = True               # Velocidad de descarga
# )
# ```

# %%
# Ejemplo con Bitcoin
btc = yf.download("BTC-USD", start="2023-01-01", end="2023-12-31")
btc.head() # .head() muestra solo las primeras 5 filas
# Out:
# /tmp/ipykernel_794/2830214085.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   btc = yf.download("BTC-USD", start="2023-01-01", end="2023-12-31")
# [*********************100%***********************]  1 of 1 completed
# Price              Close          High           Low          Open  \
# Ticker           BTC-USD       BTC-USD       BTC-USD       BTC-USD
# Date
# 2023-01-01  16625.080078  16630.439453  16521.234375  16547.914062
# 2023-01-02  16688.470703  16759.343750  16572.228516  16625.509766
# 2023-01-03  16679.857422  16760.447266  16622.371094  16688.847656
# 2023-01-04  16863.238281  16964.585938  16667.763672  16680.205078
# 2023-01-05  16836.736328  16884.021484  16790.283203  16863.472656
#
# Price            Volume
# Ticker          BTC-USD
# Date
# 2023-01-01   9244361700
# 2023-01-02  12097775227
# 2023-01-03  13903079207
# 2023-01-04  18421743322
# 2023-01-05  13692758566

# %% [markdown]
# **Importar Múltiples Acciones y el "Doble Índice"**
#
# Aquí es donde se pone interesante. Si pides varias acciones a la vez, yfinance crea una tabla con Multi-Index (un índice doble en las columnas).

# %%
# Descargamos datos para Microsoft, Google y Tesla
tickers = ["MSFT", "GOOG", "TSLA"]
data = yf.download(tickers, period="1mo")

# Mostramos las primeras filas
data.head(10)
# Out:
# /tmp/ipykernel_794/470276198.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   data = yf.download(tickers, period="1mo")
# [*********************100%***********************]  3 of 3 completed
# Price            Close                                High              \
# Ticker            GOOG        MSFT        TSLA        GOOG        MSFT
# Date
# 2026-02-09  324.399994  412.658142  417.320007  327.739990  413.945213
# 2026-02-10  318.630005  412.328857  425.209991  321.630005  422.715155
# 2026-02-11  311.329987  403.449127  428.269989  321.045013  415.511591
# 2026-02-12  309.369995  400.924896  417.070007  316.480011  405.274983
# 2026-02-13  306.019989  400.406097  417.440002  308.890015  404.616489
# 2026-02-17  302.820007  395.956238  410.630005  304.890015  399.607907
# 2026-02-18  303.940002  398.690002  411.320007  305.910004  401.643253
# 2026-02-19  303.559998  398.459991  411.709991  306.029999  404.429993
# ...

# %% [markdown]
# **¿Cómo trabajar con el doble índice?**
#
# Al descargar varias acciones, las columnas se organizan así: Primero el tipo de precio (ej. Close) y debajo el Ticker (ej. MSFT).

# %%
# Si quieres ver solo los precios de CIERRE de todas las acciones:
precios_cierre = data['Close']
precios_cierre.head()
# Out:
# Ticker            GOOG        MSFT        TSLA
# Date
# 2026-02-09  324.399994  412.658142  417.320007
# 2026-02-10  318.630005  412.328857  425.209991
# 2026-02-11  311.329987  403.449127  428.269989
# 2026-02-12  309.369995  400.924896  417.070007
# 2026-02-13  306.019989  400.406097  417.440002

# %%
# Si quieres ver solo los datos de Microsoft:
# Usamos .xs (cross-section) para entrar al segundo nivel de las columnas
msft_data = data.xs('MSFT', axis=1, level=1)
msft_data.head()
# Out:
# Price            Close        High         Low        Open    Volume
# Date
# 2026-02-09  412.658142  413.945213  399.957120  403.928068  45480500
# 2026-02-10  412.328857  422.715155  411.760179  418.664403  44857900
# 2026-02-11  403.449127  415.511591  400.096794  415.232230  42491000
# 2026-02-12  400.924896  405.274983  397.103632  404.077704  40802400
# 2026-02-13  400.406097  404.616489  397.143525  403.528974  34091600

# %%
# Graficar comparativas de varios tickers
precios_cierre.plot()
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# **Estados Financieros y Noticias**
#
# Para un análisis fundamental, necesitamos los libros de la empresa.

# %%
empresa = yf.Ticker("MSFT")

# 1. Balance General (Balance Sheet)
balance = empresa.balance_sheet
print(balance)
# Out:
#                                                     2025-06-30    2024-06-30  \
# Ordinary Shares Number                            7.434159e+09  7.434139e+09
# Share Issued                                      7.434159e+09  7.434139e+09
# Net Debt                                          1.290900e+10  3.331500e+10
# Total Debt                                        6.058800e+10  6.712700e+10
# Tangible Book Value                               2.013660e+11  1.216600e+11
# ...                                                        ...           ...
# Cash Cash Equivalents And Short Term Investments  9.455500e+10  7.553100e+10
# Other Short Term Investments                      6.431300e+10  5.721600e+10
# Cash And Cash Equivalents                         3.024200e+10  1.831500e+10
# Cash Equivalents                                  1.853100e+10  6.744000e+09
# Cash Financial                                    1.171100e+10  1.157100e+10
#
# ...

# %%
# 2. Estado de Resultados (Income Statement)
estado_resultados = empresa.financials
print(estado_resultados)
# Out:
#                                                       2025-06-30  \
# Tax Effect Of Unusual Items                        -7.708800e+07
# Tax Rate For Calcs                                  1.760000e-01
# Normalized EBITDA                                   1.606030e+11
# Total Unusual Items                                -4.380000e+08
# Total Unusual Items Excluding Goodwill             -4.380000e+08
# Net Income From Continuing Operation Net Minori...  1.018320e+11
# Reconciled Depreciation                             3.415300e+10
# Reconciled Cost Of Revenue                          8.783100e+10
# EBITDA                                              1.601650e+11
# EBIT                                                1.260120e+11
# Net Interest Income                                 2.620000e+08
# Interest Expense                                    2.385000e+09
# Interest Income                                     2.647000e+09
# ...

# %%
# 3. Noticias relevantes
noticias = empresa.news
# Mostramos el titular de la primera noticia
print(f"Última noticia: {noticias[0]['content']['title']}")
# Out:
# Última noticia: Is Oracle’s Massive $500 Billion Stargate Project in Trouble?

# %%
# explorando todas las noticias
# el resultado es un archivo json
noticias
# Out:
# [{'id': 'c967d1c9-9e4b-314b-871c-078eb79a0c68',
#   'content': {'id': 'c967d1c9-9e4b-314b-871c-078eb79a0c68',
#    'contentType': 'STORY',
#    'title': 'Is Oracle’s Massive $500 Billion Stargate Project in Trouble?',
#    'description': '',
#    'summary': 'Last year, Oracle (NYSE:ORCL) announced a massive, $500 billion data center project in Texas that signed on major AI stocks as partners. The Stargate initiative was positioned as a transformative leap for the company’s cloud business, promising to power next-generation AI workloads and deliver outsized revenue growth. While questions loomed about Oracle financials and the ... Is Oracle’s Massive $500 Billion Stargate Project in Trouble?',
#    'pubDate': '2026-03-07T16:46:57Z',
#    'displayTime': '2026-03-07T16:46:57Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/24_7_wall_st__718/81e640587f70ba6b184851e229e0447b',
# ...

# %%
# normalizar noticias a una tabla con 3 columnas
# instanciamos una lista vacia
news_data = []

# iteramos por cada elemento del json para extraer titulo, pubDate y summary
for item in noticias:
    content = item.get('content', {})
    # cada elemento lo adjuntamos a la instancia vacia
    news_data.append({
        'title': content.get('title'),
        'date': content.get('pubDate'), # 'pubDate' seems to be the correct key for date
        'summary': content.get('summary')
    })

# crear el dataframe noticias con el elemento que contiene cada noticia
df_noticias = pd.DataFrame(news_data)
df_noticias
# Out:
#                                                title                  date  \
# 0  Is Oracle’s Massive $500 Billion Stargate Proj...  2026-03-07T16:46:57Z
# 1  TQQQ Holders Face a Risk That Has Nothing to D...  2026-03-07T16:07:48Z
# 2  Stock Market Week: Sell Rules, Watchlists, Inf...  2026-03-07T14:20:59Z
# 3  A Look At Dominion Energy (D) Valuation After ...  2026-03-07T11:08:24Z
# 4  Why Wells Fargo Sees Promise in SentinelOne (S...  2026-03-07T11:01:06Z
# 5         Boeing Sends Liquid Robots to Defend Japan  2026-03-07T10:25:00Z
# 6  Microsoft Balances Japan Antitrust Pressure Wi...  2026-03-07T04:18:31Z
# 7  White House eyes ‘any lawful use’ mandate for ...  2026-03-07T03:58:42Z
# 8  Minecraft Creator Calls Using AI To Write Code...  2026-03-07T01:00:41Z
# 9  Claar Advisors Initiates Stake in Callaway as ...  2026-03-06T21:41:48Z
#
#                                              summary
# 0  Last year, Oracle (NYSE:ORCL) announced a mass...
# ...

# %% [markdown]
# **Resultado:** balance_sheet y financials te devuelven tablas con datos anuales (o trimestrales si usas `.quarterly_balance_sheet`).

# %% [markdown]
# **Visualización de Datos**
#
# Como dicen en finanzas: "un gráfico vale más que mil balances". Usaremos la librería `matplotlib` que viene integrada con los DataFrames de Pandas.

# %%
import matplotlib.pyplot as plt

# Descargamos datos de un año para Tesla
tesla = yf.download("TSLA", period="1y")

# Graficamos el precio de cierre ajustado
tesla['Close', 'TSLA'].plot(figsize=(10, 6), color='blue')

# Añadimos títulos y etiquetas para que se vea profesional
plt.title('Evolución del Precio de Tesla (Último Año)')
plt.xlabel('Fecha')
plt.ylabel('Precio en USD')
plt.grid(True) # Añadimos una cuadrícula
plt.show()
# Out:
# /tmp/ipykernel_794/952699203.py:4: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   tesla = yf.download("TSLA", period="1y")
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# **Resumen de Comandos Clave**
#
# * `yf.Ticker("AAPL")`: Crea la conexión con la empresa.
#
# * `.history(period="max")`: Descarga todos los precios históricos disponibles.
#
# * `.info` : Diccionario con datos generales (sector, empleados, resumen).
#
# * `.dividends` : Historial de pagos de dividendos.
#
# * `.actions` : Muestra splits y dividendos juntos.

# %% [markdown]
# ### Extracción de Empresas IBEX35

# %%
# 1. Definimos los tickers con el sufijo .MC (Mercado Continuo)
# Inditex (ITX), Santander (SAN), Iberdrola (IBE)
tickers_ibex = ["ITX.MC", "SAN.MC", "IBE.MC"]

# 2. Descargamos la información de mercado
datos_ibex = yf.download(tickers_ibex, period="1y")['Close']

# 3. Mostramos las últimas filas para ver los precios actuales
print(datos_ibex.tail())
# Out:
# /tmp/ipykernel_794/1053940545.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   datos_ibex = yf.download(tickers_ibex, period="1y")['Close']
# [*********************100%***********************]  3 of 3 completed
# Ticker         IBE.MC     ITX.MC  SAN.MC
# Date
# 2026-03-02  19.795000  54.060001  10.268
# 2026-03-03  19.065001  51.700001   9.609
# 2026-03-04  19.365000  53.259998   9.982
# 2026-03-05  19.299999  53.020000   9.701
# 2026-03-06  19.215000  51.880001   9.582

# %%
# Calculamos el rendimiento acumulado partiendo de base 100
rendimiento = (datos_ibex / datos_ibex.iloc[0]) * 100

print(datos_ibex.head(3))
print(rendimiento.head(3))
# Out:
# Ticker         IBE.MC     ITX.MC    SAN.MC
# Date
# 2025-03-06  12.866482  48.450912  6.125310
# 2025-03-07  13.063614  48.702053  6.039900
# 2025-03-10  13.217473  48.489552  5.775903
# Ticker          IBE.MC      ITX.MC      SAN.MC
# Date
# 2025-03-06  100.000000  100.000000  100.000000
# 2025-03-07  101.532137  100.518340   98.605612
# 2025-03-10  102.727950  100.079749   94.295674

# %%
# Graficamos
rendimiento.plot(figsize=(10, 5))
import matplotlib.pyplot as plt
plt.title("Rendimiento Relativo: Inditex vs Santander vs Iberdrola")
plt.ylabel("Base 100")
plt.show()

# %% [markdown]
# ### El método `.info`

# %% [markdown]
# El método `.info` es una de las herramientas más potentes para el análisis de datos, ya que devuelve un diccionario de Python con metadatos y métricas fundamentales extraídas directamente de Yahoo Finance.
#
# Sin embargo, debes tener en cuenta que los campos disponibles **varían según el tipo de instrumento** (una acción tiene `forwardPE`, pero un ETF o una criptomoneda no).
#
# A continuación las categorías principales de características (features) que puedes extraer:

# %% [markdown]
# **1. Métricas de Identificación y Perfil**
# Son datos básicos para categorizar el activo en tu análisis de clustering.
#
# * `shortName` / `longName`: Nombre oficial del fondo o empresa.
#
# * `quoteType`: Tipo de activo (EQUITY, ETF, CRYPTOCURRENCY).
#
# * `symbol`: El ticker (ej. "VOO").
#
# * `longBusinessSummary`: Descripción textual (útil si quieres hacer procesamiento de lenguaje natural o NLP para agrupar por temas).
#
# **2. Métricas de Riesgo y Rendimiento (Claves para Clustering)**
# Estas son las más importantes para tu modelo matemático:
#
# * `beta` / `beta3Year`: Mide la volatilidad relativa al mercado. Fundamental para separar activos refugio de activos de riesgo.
#
# * `yield` / `dividendYield`: El rendimiento por dividendo. Clave para identificar clusters de "Income" (ingresos).
#
# * `fiveYearAvgDividendYield`: Estabilidad de los dividendos a largo plazo.
#
# * `trailingAnnualReturn`: Rendimiento histórico reciente.
#
# * `morningStarRiskRating`: (Solo ETFs) Calificación de riesgo de Morningstar.
#
# **3. Datos de Costes y Tamaño**
# Para comparar la eficiencia y liquidez de los instrumentos:
#
# * `annualReportExpenseRatio`: El ratio de gastos (comisiones). Diferencia claramente los fondos de gestión pasiva de los de gestión activa.
#
# * `totalAssets`: El patrimonio bajo gestión (AUM). Indica el tamaño y la relevancia del fondo.
#
# * `averageVolume`: Volumen medio de negociación (liquidez).
#
# * `marketCap`: Capitalización bursátil (para acciones).
#
# **4. Estadísticas de Precio (Acción del Precio)**
# * `fiftyTwoWeekHigh` / `fiftyTwoWeekLow`: Máximos y mínimos anuales.
#
# * `fiftyDayAverage` / `twoHundredDayAverage`: Medias móviles, útiles para detectar tendencias técnicas.
#
# * `52WeekChange`: El cambio porcentual del precio en el último año.

# %% [markdown]
# **Ejemplo de implementacion de** `.info`

# %%
# Definir tiker o lista de tickers
tickers = ["AAPL", "MSFT", "GOOGL"]

# %%
# Crear función para extraer múltiples características y convertirlas en DataFrame

def get_etf_data(ticker_list):
    all_features = []

    for symbol in ticker_list:
        etf = yf.Ticker(symbol)
        info = etf.info
        # Extraer algunas caracteristicas
        # Nota: revisa las características disponibles según el ticker
        features = {
            "Ticker": symbol,
            "Name": info.get("shortName"),
            "Category": info.get("category"),
            "Total Assets": info.get("totalAssets"),
            "Yield": info.get("yield"),
            "Expense Ratio": info.get("annualReportExpenseRatio"),
            "Beta": info.get("beta3Year"),
            "52WeekChange": info.get("52WeekChange"),
            "Three Year Return": info.get("threeYearAverageReturn"),
            "Morningstar Risk": info.get("morningStarRiskRating"),
        }
        all_features.append(features)

    return pd.DataFrame(all_features)

# %%
# crear DataFrame con múltiples tickers
df_tickers = get_etf_data(tickers)
df_tickers
# Out:
#   Ticker                   Name Category Total Assets Yield Expense Ratio  \
# 0   AAPL             Apple Inc.     None         None  None          None
# 1   MSFT  Microsoft Corporation     None         None  None          None
# 2  GOOGL          Alphabet Inc.     None         None  None          None
#
#    Beta  52WeekChange Three Year Return Morningstar Risk
# 0  None      0.131792              None             None
# 1  None      0.075758              None             None
# 2  None      0.799723              None             None

# %% [markdown]
# ### Analisis de Monedas

# %%
# 1. Definimos la lista de los "Majors" (Pares principales)
tickers_forex = ["EURUSD=X", "GBPUSD=X", "USDJPY=X", "USDCHF=X"]

# 2. Descargamos datos del último mes
# Usamos 'Adj Close' para asegurar que el precio sea el más preciso
divisas = yf.download(tickers_forex, period="1mo")['Close']
# Out:
# /tmp/ipykernel_794/1413363188.py:6: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   divisas = yf.download(tickers_forex, period="1mo")['Close']
# [*********************100%***********************]  4 of 4 completed

# %%
# 3. Normalizamos a base 100 para comparar el rendimiento porcentual
# Esto es vital porque 1.08 (Euro) y 150 (Yen) no se pueden comparar directamente
rendimiento_divisas = (divisas / divisas.iloc[0]) * 100

# 4. Graficamos
rendimiento_divisas.plot(figsize=(10, 6))
plt.title("Evolución de Divisas Principales (Base 100)")
plt.ylabel("Rendimiento Relativo")
plt.grid(True)
plt.show()

# %% [markdown]
# ### **Ejemplo: Análisis de Volatilidad del S&P500**
#
# leeremos la lista de empresas directamente desde Wikipedia usando Pandas y luego le pediremos a yfinance que nos traiga sus precios.

# %%
# 1. Leemos la tabla de Wikipedia (la función read_html devuelve una lista de tablas)
import requests

url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}
response = requests.get(url, headers=headers)
tablas = pd.read_html(response.text)

# La primera tabla [0] contiene los componentes actuales
df_sp500 = tablas[0]

# Extraemos solo la columna 'Symbol' (los tickers)
tickers = df_sp500['Symbol'].tolist()

# Yahoo Finance usa '-' en lugar de '.' para algunos tickers (ej. BRK.B -> BRK-B)
tickers = [t.replace('.', '-') for t in tickers]

print(f"Se han encontrado {len(tickers)} activos.")
# Out:
# Se han encontrado 503 activos.
# /tmp/ipykernel_794/1699777247.py:9: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   tablas = pd.read_html(response.text)

# %% [markdown]
# **Calculo de la Volatilidad**
#
# Para calcular la volatilidad, necesitamos los precios de cierre diarios.

# %%
# 2. Descargamos solo el precio de cierre ('Close') del último mes
# Usamos threads=True para que sea mucho más rápido
datos = yf.download(tickers, period="1mo")['Close']

# Eliminamos columnas que tengan muchos datos faltantes (opcional, por limpieza)
datos = datos.dropna(axis=1, thresh=15)
# Out:
# /tmp/ipykernel_794/499547221.py:3: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   datos = yf.download(tickers, period="1mo")['Close']
# [*********************100%***********************]  503 of 503 completed

# %% [markdown]
# En finanzas, la **volatilidad** suele medirse como la **desviación estándar de los retornos diarios.**
#
# **Fórmula: **
# 1. Calculamos el cambio porcentual diario.
# 2. Calculamos la desviación estándar de esos cambios.

# %%
# 3. Calcular retornos diarios (cambio porcentual entre el día actual y el anterior)
retornos = datos.pct_change()

# 4. Calcular la volatilidad (Desviación Estándar) de cada columna (acción)
volatilidad = retornos.std()

# Convertimos el resultado en un ranking ordenado de mayor a menor
ranking_volatilidad = volatilidad.sort_values(ascending=False)

# Mostramos los 5 más volátiles
print("--- Las 5 acciones más volátiles del mes ---")
print(ranking_volatilidad.head(5))
# Out:
# --- Las 5 acciones más volátiles del mes ---
# Ticker
# COIN    0.071317
# APP     0.069737
# PSKY    0.063774
# DELL    0.061875
# KEYS    0.059750
# dtype: float64

# %% [markdown]
# Cuando ejecutas este código, obtienes un número pequeño (por ejemplo, 0.035).
#
# **¿Qué significa?** Es la desviación típica diaria. Si multiplicas ese número por la raíz cuadrada de 252 (días hábiles del año), obtendrás la **volatilidad anualizada**, que es el estándar de la industria.

# %%
# Volatilidad Anualizada del top 1
vol_anual = ranking_volatilidad.iloc[0] * np.sqrt(252)
print(f"\nLa acción más volátil tiene una volatilidad anualizada de: {vol_anual:.2%}")
# Out:
# La acción más volátil tiene una volatilidad anualizada de: 113.21%

# %% [markdown]
# ### Ejemplo: Comparativa de Margen de Utilidad
#
# El Margen de Utilidad (Net Profit Margin) nos dice cuántos centavos de ganancia neta genera una empresa por cada dólar de ingresos.
#
# Para este ejercicio, compararemos a tres gigantes tecnológicos: **Apple** (AAPL), **Microsoft** (MSFT) y **Google** (GOOG).

# %%
# 1. Definimos los tickers de las empresas a comparar
tickers = ["AAPL", "MSFT", "GOOG"]
margenes = {}

for t in tickers:
    # Creamos el objeto Ticker para cada una
    empresa = yf.Ticker(t)

    # Extraemos el Estado de Resultados (Income Statement)
    # .financials devuelve los datos anuales
    estado_resultados = empresa.financials

    # Extraemos los datos más recientes (columna 0)
    # 'Net Income' es la Utilidad Neta
    # 'Total Revenue' son los Ingresos Totales
    utilidad_neta = estado_resultados.loc['Net Income'].iloc[0]
    ingresos_totales = estado_resultados.loc['Total Revenue'].iloc[0]

    # Calculamos el Margen de Utilidad (Net Margin)
    margen = (utilidad_neta / ingresos_totales) * 100

    # Guardamos el resultado en nuestro diccionario
    margenes[t] = margen

# 2. Convertimos los resultados en una tabla para visualizar mejor
df_comparativo = pd.DataFrame.from_dict(margenes, orient='index', columns=['Margen de Utilidad (%)'])

# 3. Mostramos el resultado ordenado de mayor a menor
print(df_comparativo.sort_values(by='Margen de Utilidad (%)', ascending=False))
# Out:
#       Margen de Utilidad (%)
# MSFT               36.146015
# GOOG               32.809878
# AAPL               26.915064

# %% [markdown]
# **Explicación del Código y Resultado**
#
# `empresa.financials`: Este comando nos trae una tabla donde las filas son conceptos contables. Usamos `.loc['Net Income']` para "saltar" directamente a la fila de Utilidad Neta.
#
# `.iloc[0]`: Los estados financieros en `yfinance` suelen estar ordenados de la fecha más reciente a la más antigua. Al usar `[0]`, nos aseguramos de tomar el último año fiscal reportado.
#
# **La lógica del Margen**: Un margen del **25%** significa que, tras pagar todos los costos, impuestos y gastos, la empresa se queda con $0.25 de cada dólar vendido.
#
# **¿Por qué es útil esto para una persona de finanzas?**
#
# **Eficiencia Operativa**: Si dos empresas venden lo mismo pero una tiene un margen del 30% y la otra del 15%, la primera es mucho más eficiente convirtiendo ventas en ganancias.
#
# **Detección de Ventajas Competitivas**: Las empresas con "fosos económicos" (moats) suelen mantener márgenes altos y estables a lo largo del tiempo.

# %%
df_comparativo.plot(kind='bar', color='skyblue', legend=False)
plt.title('Comparativa de Margen de Utilidad Neta')
plt.ylabel('Porcentaje (%)')
plt.show()

# %% [markdown]
# # Analisis de Datos

# %% [markdown]
# ## Primeros pasos

# %%
# !pip install pygwalker -q
# !pip install -q ydata-profiling
# !pip install -q dtale
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 46.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 956.2/956.2 kB 48.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.2/100.2 kB 7.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 76.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 67.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 95.6 MB/s eta 0:00:00

# %%
import dtale.app as dtale_app

dtale_app.USE_COLAB = True

# %%
# !pip install -U pip setuptools wheel
# !pip install dataprep

# %%
import pandas as pd
import numpy as np
import pygwalker as pyg

from ydata_profiling import ProfileReport
import webbrowser

import yfinance as yf

# %%
data = pd.read_csv('https://raw.githubusercontent.com/PabloJMoreno/dataset/refs/heads/main/Loanclients.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Month                1000 non-null   int64
#  1   credit_amount        1000 non-null   int64
#  2   credit_term          1000 non-null   int64
#  3   Age                  1000 non-null   int64
#  4   sex                  1000 non-null   int64
#  5   education            1000 non-null   object
#  6   product_type         1000 non-null   int64
#  7   having_children_flg  1000 non-null   int64
#  8   region               1000 non-null   int64
#  9   income               967 non-null    float64
#  10  family_status        1000 non-null   int64
#  11  phone_operator       1000 non-null   int64
#  12  is_client            1000 non-null   int64
#  13  target               1000 non-null   int64
# dtypes: float64(1), int64(12), object(1)
# memory usage: 109.5+ KB

# %%
data.describe()
# Out:
#              Month  credit_amount  credit_term        Age         sex  \
# count  1000.000000    1000.000000  1000.000000  1000.0000  1000.00000
# mean      5.888000   28622.500000     7.846000    34.8990     0.27700
# std       3.279666   27423.480651     5.488206    10.5269     0.44774
# min       1.000000    5000.000000     2.000000    20.0000     0.00000
# 25%       3.000000   13000.000000     3.000000    26.0000     0.00000
# 50%       6.000000   21000.000000     6.000000    33.0000     0.00000
# 75%       9.000000   32000.000000    16.000000    42.0000     1.00000
# max      12.000000  221000.000000    17.000000    82.0000     1.00000
#
#        product_type  having_children_flg       region         income  \
# count   1000.000000          1000.000000  1000.000000     967.000000
# mean       0.915000             0.433000     1.420000   31668.045502
# std        0.961613             0.495739     1.720628   18232.125385
# ...

# %%
# data_pyg = pyg.walk(data)

# %%
msft = yf.Ticker('MSFT')
msft = msft.history(period='1y')
msft.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2025-03-07 00:00:00-05:00  389.339370  391.800508  382.610882  390.321838
# 2025-03-10 00:00:00-04:00  382.908598  383.464341  374.354093  377.271759
# 2025-03-11 00:00:00-04:00  376.120544  383.067362  374.046426  377.559540
# 2025-03-12 00:00:00-04:00  380.040547  382.293290  376.070938  380.358093
# 2025-03-13 00:00:00-04:00  380.248934  382.392527  374.582325  375.892273
#
#                              Volume  Dividends  Stock Splits
# Date
# 2025-03-07 00:00:00-05:00  22034100        0.0           0.0
# 2025-03-10 00:00:00-04:00  32840100        0.0           0.0
# 2025-03-11 00:00:00-04:00  30380200        0.0           0.0
# 2025-03-12 00:00:00-04:00  24253600        0.0           0.0
# 2025-03-13 00:00:00-04:00  20473000        0.0           0.0

# %%
# graph_yfina = pyg.walk(msft)

# %%
dtale_app.show(data=data)
# Out:
# https://40000-m-s-2h8t3799d9rjx-c.us-east1-0.prod.colab.dev/dtale/main/1

# %%
msft.columns
# Out:
# Index(['Open', 'High', 'Low', 'Close', 'Volume', 'Dividends', 'Stock Splits'], dtype='object')

# %%
msft[['Close','High','Low']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
msft['Close'].rolling(window=20).mean()
# Out:
# Date
# 2025-03-07 00:00:00-05:00           NaN
# 2025-03-10 00:00:00-04:00           NaN
# 2025-03-11 00:00:00-04:00           NaN
# 2025-03-12 00:00:00-04:00           NaN
# 2025-03-13 00:00:00-04:00           NaN
#                                 ...
# 2026-03-02 00:00:00-05:00    401.305481
# 2026-03-03 00:00:00-05:00    400.381686
# 2026-03-04 00:00:00-05:00    400.128009
# 2026-03-05 00:00:00-05:00    399.999669
# 2026-03-06 00:00:00-05:00    400.808992
# Name: Close, Length: 251, dtype: float64

# %%
msft['sma_20'] = msft['Close'].rolling(window=20).mean()

# %%
msft[['Close','sma_20']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
msft['bol_max'] = msft['sma_20'] + (msft['Close'].rolling(window=20).std() * 2)
msft['bol_min'] = msft['sma_20'] - (msft['Close'].rolling(window=20).std() * 2)

msft[['Close', 'sma_20', 'bol_min', 'bol_max']].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
msft['ema_10'] = msft['Close'].ewm(span=10, adjust=False).mean()

# %%
media_geo = np.exp(np.log(msft['Close']).mean())
media_geo
# Out:
# np.float64(461.90100074731515)

# %% [markdown]
# ## Analisis de Datos

# %%
df = pd.read_csv('https://raw.githubusercontent.com/emrangel/Course_Data_Financial/refs/heads/main/Course/class/data/titanic.csv')

# %%
profile = ProfileReport(df, title="Profiling Report")

profile.to_file("reporte.html")

webbrowser.open("reporte.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# False

# %%
# profile

# %%
profile = ProfileReport(
    df,
    title="Correlaciones",
    explorative=True,
    correlations={
        "pearson": {"calculate": True},
        "spearman": {"calculate": True},
        "kendall": {"calculate": True},
        "phi_k": {"calculate": True},
        "cramers": {"calculate": True},
    },
    interactions=None,
    missing_diagrams=None,
    samples=None,
)

profile.to_file("correlaciones.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ## Data Caos

# %%
import pandas as pd
import numpy as np
# import dataprep.clean as clean
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_20917/644042135.py in <cell line: 0>()
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import dataprep.clean as clean
#
# ModuleNotFoundError: No module named 'dataprep'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
df = pd.read_csv('https://raw.githubusercontent.com/emrangel/Course_Data_Financial/refs/heads/main/Course/class/data/dataset_caos.csv')

# %%
df.head()
# Out:
#    Unnamed: 0                          fecha País_Destino!!  \
# 0           0  1996.07.10 AD at 15:08:56 PDT         U.S.A.
# 1           1       Thu Sep 25 10:36:28 2003  united states
# 2           2  Thu Sep 25 10:36:28 BRST 2003            USA
# 3           3  2003 10:36:28 BRST 25 Sep Thu          U S A
# 4           4       Thu Sep 25 10:36:28 2003         España
#
#       e-mail_C0ntacto# Categoría_Prod ($)  \
# 0       juan@gmail.com        Electrónica
# 1  pedro.perez@outlook        electronica
# 2     maria@yahoo..com        ELECTRÓNICA
# 3      luis@ gmail.com            Electro
# 4      ana@Hotmail.com              Hogar
#
#                        Observaciones_Libres!!!@#
# 0  ¡¡Hola!! Visita http://site.com para + info 😊
# 1    Texto con <html>etiquetas</html> y @usuario
# 2        Muchos espacios    innecesarios   aquí.
# 3             Carácteres raros: ø, é, ñ, ü, ß...
# 4                        1234567890: !#$%&/()=?¿

# %%
df.drop(columns=['Unnamed: 0'], inplace=True)

# %%
df.head(2)
# Out:
#                            fecha País_Destino!!     e-mail_C0ntacto#  \
# 0  1996.07.10 AD at 15:08:56 PDT         U.S.A.       juan@gmail.com
# 1       Thu Sep 25 10:36:28 2003  united states  pedro.perez@outlook
#
#   Categoría_Prod ($)                      Observaciones_Libres!!!@#
# 0        Electrónica  ¡¡Hola!! Visita http://site.com para + info 😊
# 1        electronica    Texto con <html>etiquetas</html> y @usuario
